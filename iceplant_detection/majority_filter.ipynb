# %%
import os
import time
import numpy as np
import pandas as pd

import rasterio
import xarray as xr
import rioxarray as rioxr

#import raster_to_features as rm

#from shapely.geometry import Polygon

import matplotlib.pyplot as plt

#from scipy import stats
#from scipy.ndimage import generic_filter

# %%
from dask_image.ndfilters import generic_filter
import dask_image.imread
#import dask.array as da

import dask_gateway

# %%
# initialize DASK cluster
cluster = dask_gateway.GatewayCluster()
cluster.scale(30)

client = cluster.get_client()
client
# Out:
# <Client: 'tls://10.244.72.152:8786' processes=0 threads=0, memory=0 B>

# %%
# ---------------------------------------
# https://stackoverflow.com/questions/54439298/image-filter-which-uses-the-highest-occurence-of-pixel-values
# Modal filter
def modal(P):
    """We receive P[0]..P[8] with the pixels in the 3x3 surrounding window"""
    mode = stats.mode(P)
    return mode.mode[0]

# %%
fp = os.path.join(os.getcwd(),
                  'temp',
                  '2012_spectral_predictions',
                  'S_clip_preds_ca_m_3411933_ne_11_1_20120505_20120730.tif')
#os.path.exists(fp)
#raster = rioxr.open_rasterio(href, chunks={"x": int(x_n/workers_sqrt), "y":int(y_n/workers_sqrt)})

# %%
# img = dask_image.imread.imread(fp)
# img = img.squeeze()
# img

# %%
img.compute()

# %%
raster = rioxr.open_rasterio(fp)
raster = raster.squeeze()
raster
# Out:
# <xarray.DataArray (y: 1288, x: 3388)>
# [4363744 values with dtype=uint8]
# Coordinates:
#     band         int64 1
#   * x            (x) float64 2.298e+05 2.298e+05 ... 2.332e+05 2.332e+05
#   * y            (y) float64 3.815e+06 3.815e+06 ... 3.814e+06 3.814e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
# values = xr.open_dataarray(fp, chunks={'x': 1000, 'y': 1000})
# values = values.squeeze()
# values
# Out:
# <xarray.DataArray 'band_data' (y: 1288, x: 3388)>
# dask.array<getitem, shape=(1288, 3388), dtype=float32, chunksize=(1000, 1000), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 1
#   * x            (x) float64 2.298e+05 2.298e+05 ... 2.332e+05 2.332e+05
#   * y            (y) float64 3.815e+06 3.815e+06 ... 3.814e+06 3.814e+06
#     spatial_ref  int64 ...
# Attributes:
#     AREA_OR_POINT:  Area

# %%
values.close()

# %%
# raster_xr = rioxr.open_rasterio(fp, chunks={'x': 300, 'y': 300})
# raster_xr = raster_xr.squeeze()
# raster_xr

# %%
filtered = generic_filter(values.data, modal, (3, 3))

# %%
filtered.visualize()

# %%
t_alpha = time.time()
results = filtered.compute()
print(time.time() - t_alpha)

# %%
plt.imshow(preds_20, interpolation='none')
plt.show()

# %%
values.compute()
# Out:
# ---------------------------------------------------------------------------
# RasterioIOError                           Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 values.compute()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataarray.py:993, in DataArray.compute(self, **kwargs)
#     974 """Manually trigger loading of this array's data from disk or a
#     975 remote source into memory and return a new array. The original is
#     976 left unaltered.
#    (...)
#     990 dask.compute
#     991 """
#     992 new = self.copy(deep=False)
# --> 993 return new.load(**kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataarray.py:967, in DataArray.load(self, **kwargs)
#     949 def load(self: T_DataArray, **kwargs) -> T_DataArray:
#     950     """Manually trigger loading of this array's data from disk or a
#     951     remote source into memory and return this array.
#     952
#    (...)
# ...

# %%
msai4earth-esa/iceplant_detection/temp/2012_spectral_predictions/S_clip_preds_ca_m_3411933_ne_11_1_20120505_20120730.tif
msai4earth-esa/iceplant_detection/temp/2012_spectral_predictions/S_clip_preds_ca_m_3411933_ne_11_1_20120505_20120730.tif
